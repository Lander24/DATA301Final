# %%
import io
import pandas as pd
import numpy as np 

df_master_2020 = pd.read_csv("https://raw.githubusercontent.com/Lander24/DATA301Final/master/CombData/master.csv")
df_master_2020 = df_master_2020.drop(["Unnamed: 0"] , axis=1)
df_master = df_master_2020[df_master_2020['Year'] != 2020]
df_2020 = df_master_2020[df_master_2020['Year'] == 2020]
df_master["Drafted"] = df_master.apply(lambda row :  "Undrafted" if np.isnan(row["Round"]) else "Drafted" , axis =1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_master["Pos"].value_counts()
# Out:
# WR      462
# CB      359
# RB      294
# OT      253
# DT      231
# DE      221
# OLB     211
# TE      176
# QB      173
# OG      166
# ILB     134
# SS      100
# FS       85
# C        77
# S        56
# EDGE     47
# LB       40
# FB       39
# DL       33
# OL       25
# Name: Pos, dtype: int64

# %%
combine_train =df_master[df_master["Year"]%2==0]
combine_test = df_master[df_master["Year"]%2==1]

X_train = combine_train[["40YD"	,"Vertical",	"BenchReps",	"Broad Jump"	,"3Cone",	"Shuttle"]]
y_train = combine_train["Drafted"]
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

# Standardize the training and test data
scaler = StandardScaler()
X_train_st = scaler.fit_transform(X_train)
y_train = combine_train["Drafted"]
x_new = combine_test[["40YD"	,"Vertical",	"BenchReps",	"Broad Jump"	,"3Cone",	"Shuttle"]]

model = KNeighborsRegressor(n_neighbors=5)
model.fit(X=X_train_st, y=y_train)
model.predict(X=X_new_st)
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
          StandardScaler(),
          KNeighborsRegressor(n_neighbors=5)
)

pipeline.fit(X=X_train, y=y_train)
pipeline.predict(X=pd.DataFrame([x_new]))
# Fit k-nearest neighbors
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d020f53f13b2> in <module>()
#      14
#      15 model = KNeighborsRegressor(n_neighbors=5)
# ---> 16 model.fit(X=X_train_st, y=y_train)
#      17 model.predict(X=X_new_st)
#      18 from sklearn.pipeline import make_pipeline
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1104         """
#    1105         if not isinstance(X, (KDTree, BallTree)):
# -> 1106             X, y = check_X_y(X, y, "csr", multi_output=True)
#    1107         self._y = y
#    1108         return self._fit(X)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
combine_train =df_master[df_master["Year"]%2==0]
combine_test = df_master[df_master["Year"]%2==1]

# %%
print(combine_train)

combine_train = combine_train[combine_train["Pos"] == "DE"]
combine_test = combine_test[combine_test["Pos"] == "DE"]
print(combine_train)

combine_train = combine_train[["Player", "40YD"	,"Vertical",	"Broad Jump",	 "BenchReps","Drafted"]].dropna()
combine_test = combine_test[["Player","40YD"	,"Vertical"	,	"Broad Jump"	, "BenchReps", "Drafted"]].dropna()
# Out:
#       Year             Player   Pos  ...  Round   Pick    Drafted
# 0     2010          Sam Young    OT  ...    6.0  179.0    Drafted
# 1     2010     Trent Williams    OT  ...    1.0    4.0    Drafted
# 2     2010   Stephen Williams    WR  ...    NaN    NaN  Undrafted
# 3     2010      Mike Williams    WR  ...    4.0  101.0    Drafted
# 4     2010      Kyle Williams    WR  ...    6.0  206.0    Drafted
# ...    ...                ...   ...  ...    ...    ...        ...
# 2847  2018         Tony Brown    CB  ...    NaN    NaN  Undrafted
# 2848  2018       Jessie Bates     S  ...    NaN    NaN  Undrafted
# 2849  2018        John Atkins    DT  ...    NaN    NaN  Undrafted
# 2850  2018  Dorance Armstrong  EDGE  ...    NaN    NaN  Undrafted
# 2851  2018        Ola Adeniyi  EDGE  ...    NaN    NaN  Undrafted
#
# [1590 rows x 19 columns]
#       Year               Player Pos  ...  Round   Pick    Drafted
# 158   2010         Willie Young  DE  ...    7.0  213.0    Drafted
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline

print(combine_train)


X_train = combine_train[["40YD"	,"Vertical",	"Broad Jump"	, "BenchReps"]]
y_train = combine_train["Drafted"]
y_test = combine_test["Drafted"]

X_test = combine_test[["40YD"	,"Vertical",	"Broad Jump"	,"BenchReps"]]


# define a pipeline
pipeline = make_pipeline(
    StandardScaler(),
    KNeighborsClassifier(n_neighbors=10)
)

# fit the pipeline (using X_train and y_train defined above)
pipeline.fit(X_train, y_train)

# define the test data (recall that scikit-learn expects a 2D-array)
# Out:
#                    Player  40YD  Vertical  Broad Jump  BenchReps    Drafted
# 158          Willie Young  4.88      38.0       118.0       25.0    Drafted
# 167           C.J. Wilson  4.83      33.0       116.0       32.0    Drafted
# 184   Daniel Te'o-Nesheim  4.73      37.0       121.0       29.0    Drafted
# 195         George Selvie  4.93      30.5       109.0       24.0    Drafted
# 203     Jason Pierre-Paul  4.71      30.5       115.0       19.0    Drafted
# ...                   ...   ...       ...         ...        ...        ...
# 2795        Bradley Chubb  4.65      36.0       121.0       24.0    Drafted
# 2801         Andrew Brown  5.03      28.0       101.0       31.0    Drafted
# 2808            Ade Aruna  4.60      38.5       128.0       18.0    Drafted
# 2837         Dashawn Hand  4.83      31.5       111.0       28.0  Undrafted
# 2839  John Franklin-Myers  4.75      33.0       113.0       26.0  Undrafted
#
# [78 rows x 6 columns]
# Pipeline(memory=None,
# ...

# %%
y_per = pipeline.predict_proba(X_test)
X_test
df_master.loc[3097]
from sklearn.metrics import precision_score, recall_score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-00abfa209493> in <module>()
#       4 from sklearn.metrics import precision_score, recall_score
#       5
# ----> 6 (precision_score(y_test == 0, y_per == 0),
#       7  recall_score(y_test == 0, y_per == 0))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1670                                                  warn_for=('precision',),
#    1671                                                  sample_weight=sample_weight,
# -> 1672                                                  zero_division=zero_division)
#    1673     return p
#    1674
#
# ...

# %%
combine_train = combine_train[combine_train["Pos"] == "DE"]
combine_test = combine_test[combine_test["Pos"] == "DE"]
print(combine_train)

combine_train = combine_train[["Player", "40YD"	,"Vertical",	"Broad Jump",	 "BenchReps","Pick"]].dropna()
combine_test = combine_test[["Player","40YD"	,"Vertical"	,	"Broad Jump"	, "BenchReps", "Pick"]].dropna()
# Out:
#       Year               Player Pos  ...  Round   Pick    Drafted
# 158   2010         Willie Young  DE  ...    7.0  213.0    Drafted
# 162   2010        Corey Wootton  DE  ...    4.0  109.0    Drafted
# 166   2010          E.J. Wilson  DE  ...    4.0  127.0    Drafted
# 167   2010          C.J. Wilson  DE  ...    7.0  230.0    Drafted
# 184   2010  Daniel Te'o-Nesheim  DE  ...    3.0   86.0    Drafted
# ...    ...                  ...  ..  ...    ...    ...        ...
# 2808  2018            Ade Aruna  DE  ...    6.0  218.0    Drafted
# 2821  2018      Olubunmi Rotimi  DE  ...    NaN    NaN  Undrafted
# 2837  2018         Dashawn Hand  DE  ...    NaN    NaN  Undrafted
# 2839  2018  John Franklin-Myers  DE  ...    NaN    NaN  Undrafted
# 2842  2018       Matt Dickerson  DE  ...    NaN    NaN  Undrafted
#
# [119 rows x 19 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline

print(combine_train)


X_train = combine_train[["40YD"	,"Vertical",	"Broad Jump"	, "BenchReps"]]
y_train = combine_train["Pick"]

X_test = combine_test[["40YD"	,"Vertical",	"Broad Jump"	,"BenchReps"]]


# define a pipeline
pipeline = make_pipeline(
    StandardScaler(),
    KNeighborsClassifier(n_neighbors=10)
)

# fit the pipeline (using X_train and y_train defined above)
pipeline.fit(X_train, y_train)

# define the test data (recall that scikit-learn expects a 2D-array)

from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
          StandardScaler(),
          KNeighborsRegressor(n_neighbors=11)
)
pipeline.fit(X=X_train, y=y_train)
pipeline.predict(X_test)
print(pipeline.predict(X_test))
print(y_train)
# Out:
#                    Player  40YD  Vertical  Broad Jump  BenchReps   Pick
# 158          Willie Young  4.88      38.0       118.0       25.0  213.0
# 167           C.J. Wilson  4.83      33.0       116.0       32.0  230.0
# 184   Daniel Te'o-Nesheim  4.73      37.0       121.0       29.0   86.0
# 195         George Selvie  4.93      30.5       109.0       24.0  226.0
# 203     Jason Pierre-Paul  4.71      30.5       115.0       19.0   15.0
# 234         Jammie Kirlew  5.05      33.0       111.0       26.0  232.0
# 248            Greg Hardy  4.82      35.0       117.0       21.0  175.0
# 257      Clifton Geathers  4.98      36.0       112.0       26.0  186.0
# 261         Carlos Dunlap  4.68      31.5       111.0       21.0   54.0
# 293          Tyson Alualu  4.87      35.5       116.0       21.0   10.0
# 801            Billy Winn  4.86      27.0       107.0       24.0  205.0
# 806        Olivier Vernon  4.73      34.5       122.0       31.0   72.0
# ...

# %%
import numpy as np
df_2020_wr = df_2020[df_2020["Pos"] =="WR"]
df_2020_wr = df_2020_wr[np.isnan(df_2020_wr["40YD"]) == False]
df_2020_wr = df_2020_wr[np.isnan(df_2020_wr["Vertical"]) == False]
df_2020_wr = df_2020_wr[np.isnan(df_2020_wr["Broad Jump"]) == False]
df_2020_wr
# Out:
#       Year                 Player Pos  ...  Height_Inches  Round Pick
# 3188  2020             Cody White  WR  ...             75    NaN  NaN
# 3191  2020            Jeff Thomas  WR  ...             69    NaN  NaN
# 3198  2020          Freddie Swain  WR  ...             72    NaN  NaN
# 3208  2020        Henry Ruggs III  WR  ...             71    NaN  NaN
# 3209  2020        Kendrick Rogers  WR  ...             76    NaN  NaN
# 3210  2020               Joe Reed  WR  ...             72    NaN  NaN
# 3211  2020           Jalen Reagor  WR  ...             71    NaN  NaN
# 3213  2020        Michael Pittman  WR  ...             76    NaN  NaN
# 3218  2020          Malcolm Perry  WR  ...             69    NaN  NaN
# 3219  2020  Donovan Peoples-Jones  WR  ...             74    NaN  NaN
# 3222  2020          Dezmon Patmon  WR  ...             76    NaN  NaN
# 3224  2020            K.J. Osborn  WR  ...             71    NaN  NaN
# ...

# %%
combine_train =df_master[df_master["Year"]%2==0]

combine_train = combine_train[combine_train["Pos"] == "WR"]
print(combine_train)

combine_train = combine_train[np.isnan(combine_train["40YD"]) == False]
combine_train = combine_train[np.isnan(combine_train["Vertical"]) == False]
combine_train = combine_train[np.isnan(combine_train["Broad Jump"]) == False]
combine_train = combine_train[np.isnan(combine_train["Pick"]) == False]
combine_train
# Out:
#       Year                Player Pos  ...  Round   Pick    Drafted
# 2     2010      Stephen Williams  WR  ...    NaN    NaN  Undrafted
# 3     2010         Mike Williams  WR  ...    4.0  101.0    Drafted
# 4     2010         Kyle Williams  WR  ...    6.0  206.0    Drafted
# 6     2010       Damian Williams  WR  ...    3.0   77.0    Drafted
# 7     2010           Blair White  WR  ...    NaN    NaN  Undrafted
# ...    ...                   ...  ..  ...    ...    ...        ...
# 2677  2018          Richie James  WR  ...    NaN    NaN  Undrafted
# 2681  2018         Davon Grayson  WR  ...    NaN    NaN  Undrafted
# 2682  2018         Robert Foster  WR  ...    NaN    NaN  Undrafted
# 2687  2018            D.J. Chark  WR  ...    NaN    NaN  Undrafted
# 2688  2018  Darren Carrington II  WR  ...    NaN    NaN  Undrafted
#
# [229 rows x 19 columns]
#       Year            Player Pos   Age  ...  Height_Inches Round   Pick  Drafted
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline

print(df_2020_wr)


X_train = combine_train[["40YD"	,"Vertical",	"Broad Jump"]]
y_train = combine_train["Pick"]

X_test = df_2020_wr[["40YD"	,"Vertical",	"Broad Jump"]]


# define a pipeline
pipeline = make_pipeline(
    StandardScaler(),
    KNeighborsClassifier(n_neighbors=10)
)

# fit the pipeline (using X_train and y_train defined above)
pipeline.fit(X_train, y_train)

# define the test data (recall that scikit-learn expects a 2D-array)

from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
          StandardScaler(),
          KNeighborsRegressor(n_neighbors=5)
)
print(X_test)
pipeline.fit(X=X_train, y=y_train)
pipeline.predict(X_test)
y = pipeline.predict(X_test)

print(df_2020_wr["Player"])
# Out:
#       Year                 Player Pos  ...  Height_Inches  Round Pick
# 3188  2020             Cody White  WR  ...             75    NaN  NaN
# 3191  2020            Jeff Thomas  WR  ...             69    NaN  NaN
# 3198  2020          Freddie Swain  WR  ...             72    NaN  NaN
# 3208  2020        Henry Ruggs III  WR  ...             71    NaN  NaN
# 3209  2020        Kendrick Rogers  WR  ...             76    NaN  NaN
# 3210  2020               Joe Reed  WR  ...             72    NaN  NaN
# 3211  2020           Jalen Reagor  WR  ...             71    NaN  NaN
# 3213  2020        Michael Pittman  WR  ...             76    NaN  NaN
# 3218  2020          Malcolm Perry  WR  ...             69    NaN  NaN
# 3219  2020  Donovan Peoples-Jones  WR  ...             74    NaN  NaN
# 3222  2020          Dezmon Patmon  WR  ...             76    NaN  NaN
# 3224  2020            K.J. Osborn  WR  ...             71    NaN  NaN
# ...
